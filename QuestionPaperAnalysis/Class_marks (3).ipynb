# %%
import pandas as pd
import matplotlib.pyplot as plt
p = pd.read_csv("class_marks.csv")
p
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %% [markdown]
# # Reading the class_marks csv dataset

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Total   86 non-null     int64
#  1   Q1aM4   85 non-null     float64
#  2   Q1bM6   73 non-null     float64
#  3   Q2aM6   72 non-null     float64
#  4   Q2bM4   75 non-null     float64
#  5   Q3aM5   52 non-null     float64
#  6   Q3bM5   51 non-null     float64
#  7   Q4aM3   32 non-null     float64
#  8   Q4bM7   26 non-null     float64
#  9   Q5M10   56 non-null     float64
#  10  Q6aM4   33 non-null     float64
#  11  Q6bM6   28 non-null     float64
# dtypes: float64(11), int64(1)
# memory usage: 8.2 KB

# %% [markdown]
# # Structure of the dataset is observed

# %%
p = p.fillna(0)

# %% [markdown]
# # Modifying nan with zero

# %%
p = p.astype("int64")
p
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37      4      5      6      4      2      1      0      5      8
# 1      32      4      3      4      3      0      0      3      6      9
# 2      33      4      5      5      1      5      5      0      0      8
# 3      24      4      6      6      3      2      2      0      0      0
# 4      36      3      6      4      4      5      4      0      0     10
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      0
# 82     27      2      2      5      3      0      0      0      0      7
# 83     37      4      6      6      2      0      0      0      0      9
# 84     28      4      0      5      4      5      4      0      0      6
# 85     29      4      6      0      0      0      0      3      5      7
#
#     Q6aM4  Q6bM6
# 0       4      6
# 1       0      0
# 2       0      0
# 3       2      0
# ...

# %% [markdown]
# # changing float datatype into integer

# %%
p = p.replace(28,29)

# %% [markdown]
# # Replacing marks 28 with 29

# %%
p.shape
# Out:
# (86, 12)

# %% [markdown]
# # No.of rows and columns

# %%
p["Q1"]=p["Q1aM4"] + p["Q1bM6"]
p["Q2"]=p["Q2aM6"] + p["Q2bM4"]
p["Q3"]=p["Q3aM5"] + p["Q3bM5"]
p["Q4"]=p["Q4aM3"] + p["Q4bM7"]
p["Q5"]=p["Q5M10"]
p["Q6"]=p["Q6aM4"] + p["Q6bM6"]
p.drop(["Q1aM4", "Q1bM6","Q2aM6","Q2bM4" ,"Q3aM5" , "Q3bM5", "Q4aM3" ,"Q4bM7","Q5M10","Q6aM4","Q6bM6"], axis=1, inplace=True)

# %% [markdown]
# # Combine columns as single named columns

# %%
p.head(10)
# Out:
#    Total  Q1  Q2  Q3  Q4  Q5  Q6
# 0     37   9  10   3   5   8  10
# 1     32   7   7   0   9   9   0
# 2     33   9   6  10   0   8   0
# 3     24  10   9   4   0   0   2
# 4     36   9   8   9   0  10   0
# 5     20  10  10   0   0   0   0
# 6     25   7   2  10   0   6   0
# 7     34  10  10   0   2   0   3
# 8     27   8   5   0   0   9   3
# 9     35   6   9  10   0   0  10

# %% [markdown]
# # Displaying first 10 rows

# %%
p.tail(10)
# Out:
#     Total  Q1  Q2  Q3  Q4  Q5  Q6
# 76     17   5   6   6   0   0   0
# 77     22   9   0   5   2   0   6
# 78     33   5  10  10   0   8   0
# 79     27   8   3   7   0   9   0
# 80     31  10   8   7   0   6   0
# 81     32   9   7   8   0   0  10
# 82     27   4   8   0   0   7   8
# 83     37  10   8   0   0   9  10
# 84     29   4   9   9   0   6   0
# 85     29  10   0   0   8   7   5

# %% [markdown]
# # Displaying last 10 rows

# %%
p["percentage"]=((p["Total"]/60)*100).round()
p
# Out:
#     Total  Q1  Q2  Q3  Q4  Q5  Q6  percentage
# 0      37   9  10   3   5   8  10        62.0
# 1      32   7   7   0   9   9   0        53.0
# 2      33   9   6  10   0   8   0        55.0
# 3      24  10   9   4   0   0   2        40.0
# 4      36   9   8   9   0  10   0        60.0
# ..    ...  ..  ..  ..  ..  ..  ..         ...
# 81     32   9   7   8   0   0  10        53.0
# 82     27   4   8   0   0   7   8        45.0
# 83     37  10   8   0   0   9  10        62.0
# 84     29   4   9   9   0   6   0        48.0
# 85     29  10   0   0   8   7   5        48.0
#
# [86 rows x 8 columns]

# %% [markdown]
# # Calculating percentage with reference of Total

# %%
def assign_grade(percentage):
    if percentage >= 60:
        return 'A'
    elif percentage >= 50:
        return 'B'
    elif percentage >= 40:
        return 'C'
    elif percentage >= 30:
        return 'D'
    else:
        return 'F'

p['Grade'] = p['percentage'].apply(assign_grade)
p
# Out:
#     Total  Q1  Q2  Q3  Q4  Q5  Q6  percentage Grade
# 0      37   9  10   3   5   8  10        62.0     A
# 1      32   7   7   0   9   9   0        53.0     B
# 2      33   9   6  10   0   8   0        55.0     B
# 3      24  10   9   4   0   0   2        40.0     C
# 4      36   9   8   9   0  10   0        60.0     A
# ..    ...  ..  ..  ..  ..  ..  ..         ...   ...
# 81     32   9   7   8   0   0  10        53.0     B
# 82     27   4   8   0   0   7   8        45.0     C
# 83     37  10   8   0   0   9  10        62.0     A
# 84     29   4   9   9   0   6   0        48.0     C
# 85     29  10   0   0   8   7   5        48.0     C
#
# [86 rows x 9 columns]

# %% [markdown]
# # Assigning the grade

# %%
grade_counts = p["Grade"].value_counts()
plt.figure(figsize=(8, 5))
grade_counts.plot(kind="bar", color="skyblue")
plt.title("Grade Distribution")
plt.xlabel("Grade")
plt.ylabel("Number of Students")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Plotting bar graph with reference of grade

# %%
p.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Data is ploted

# %%
p.loc[5]
# Out:
# Total           20
# Q1              10
# Q2              10
# Q3               0
# Q4               0
# Q5               0
# Q6               0
# percentage    33.0
# Grade            D
# Name: 5, dtype: object

# %%
plt.hist(p['Q1'],color='red',edgecolor='black',bins=9)
plt.title("Histogram of Q1")
plt.xlabel("Marks scored in Q1")
plt.ylabel("No.of Students")
# Out:
# Text(0, 0.5, 'No.of Students')

# %% [markdown]
# # More than 18 students got 10 marks in Q1 question

# %%
plt.hist(p['Q2'],color='pink',edgecolor='purple',bins=9)
plt.title("Histogram of Q2")
plt.xlabel("Marks scored in Q2")
plt.ylabel("No.of Students")
# Out:
# Text(0, 0.5, 'No.of Students')

# %% [markdown]
# # More than 30 students got 10 marks in Q2 question

# %%
plt.hist(p['Q3'],color='blue',edgecolor='brown',bins=9)
plt.title("Histogram of Q3")
plt.xlabel("Marks scored in Q3")
plt.ylabel("No.of Students")
# Out:
# Text(0, 0.5, 'No.of Students')

# %% [markdown]
# # More than 25 students got 10 marks in Q3 question

# %%
p.boxplot(by='Q1', column =['Total'], grid = False,color='brown')
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Box plot for Q1 is plotted

# %%
p.boxplot(by='Q2', column =['Total'], grid = False,color='brown')
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Box plot for Q2 is plotted

# %%
p.boxplot(by='Q3', column =['Total'], grid = False,color='orange')
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Box plot for Q3 is plotted

# %%
p.boxplot(by='Q4', column =['Total'], grid = False,color='pink')
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Box plot for Q4 is plotted

# %%
p.boxplot(by='Q5', column =['Total'], grid = False,color='brown')
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Box plot for Q5 is plotted

# %%
import pandas as pd
import matplotlib.pyplot as plt
p=pd.read_csv("class_marks.csv")
p["Q1"]=p["Q1aM4"] + p["Q1bM6"]
p["Q2"]=p["Q2aM6"] + p["Q2bM4"]
p["Q3"]=p["Q3aM5"] + p["Q3bM5"]
p["Q4"]=p["Q4aM3"] + p["Q4bM7"]
p["Q5"]=p["Q5M10"]
p["Q6"]=p["Q6aM4"] + p["Q6bM6"]
p.drop(["Q1aM4", "Q1bM6","Q2aM6","Q2bM4" ,"Q3aM5" , "Q3bM5", "Q4aM3" ,"Q4bM7","Q5M10","Q6aM4","Q6bM6"], axis=1, inplace=True)
total_by_q5 = p.groupby('Q1')['Total'].sum()
plt.figure(figsize=(8, 6))
total_by_q5.plot(kind='pie', autopct='%d%%', colors=['brown', 'orange', 'green', 'blue', 'red'])
plt.ylabel('')
plt.title('Total by Q1')
plt.show()

# %% [markdown]
# # Pie chart of total marks for Q1 scores

# %%
total_by_q5 = p.groupby('Q2')['Total'].sum()
plt.figure(figsize=(8, 6))
total_by_q5.plot(kind='pie', autopct='%d%%', colors=['brown', 'orange', 'green', 'blue', 'red'])
plt.ylabel('')
plt.title('Total by Q2')
plt.show()

# %% [markdown]
# # Pie chart of total marks for Q2 scores

# %%
total_by_q5 = p.groupby('Q3')['Total'].sum()
plt.figure(figsize=(8, 6))
total_by_q5.plot(kind='pie', autopct='%d%%', colors=['pink', 'blue', 'yellow', 'orange', 'green'])
plt.ylabel('')
plt.title('Total by Q3')
plt.show()

# %% [markdown]
# # Pie chart of total marks for Q3 scores

# %%
total_by_q5 = p.groupby('Q4')['Total'].sum()
plt.figure(figsize=(8, 6))
total_by_q5.plot(kind='pie', autopct='%d%%', colors=['black', 'orange', 'red', 'brown', 'pink'])
plt.ylabel('')
plt.title('Total by Q4')
plt.show()

# %% [markdown]
# # Pie chart of total marks for Q4 scores

# %%
total_by_q5 = p.groupby('Q5')['Total'].sum()
plt.figure(figsize=(8, 6))
total_by_q5.plot(kind='pie', autopct='%d%%', colors=['brown', 'orange', 'green', 'blue', 'red'])
plt.ylabel('')
plt.title('Total by Q5')
plt.show()

# %% [markdown]
# # Pie chart of total marks for Q5 scores

# %%
p.plot.line(x='Q1',y='Total',color='red')
plt.title("Line Graph of Q1")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# # Line graph for Q1

# %%
p.plot.line(x='Q2',y='Total',color='blue')
plt.title("Line Graph of Q2")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# # Line graph for Q2

# %%
p.plot.line(x='Q3',y='Total',color='orange')
plt.title("Line Graph of Q3")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# # Line graph for Q3

# %%
p.plot.line(x='Q4',y='Total',color='black')
plt.title("Line Graph of Q4")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# # Line graph for Q4

# %%
p.plot.line(x='Q5',y='Total',color='pink')
plt.title("Line Graph of Q5")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# # Line graph for Q5

# %%
p.plot.scatter(x = 'Q1', y = 'Total',color='blue',s=30)
plt.title("Scatter Plot for Q1")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q1')

# %% [markdown]
# # Q1 performance on the overall total

# %%
p.plot.scatter(x = 'Q2', y = 'Total',color='yellow',s=30)
plt.title("Scatter Plot for Q2")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q2')

# %% [markdown]
# # Q2 performance on the overall total

# %%
p.plot.scatter(x = 'Q3', y = 'Total',color='brown',s=30)
plt.title("Scatter Plot for Q3")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q3')

# %% [markdown]
# # Q3 performance on the overall total

# %%
p.plot.scatter(x = 'Q4', y = 'Total',color='pink',s=30)
plt.title("Scatter Plot for Q4")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q4')

# %% [markdown]
# # Q4 performance on the overall total

# %%
p.plot.scatter(x = 'Q5', y = 'Total',color='red',s=30)
plt.title("Scatter Plot for Q5")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q5')

# %% [markdown]
# # Q5 performance on the overall total

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Installing seaborn

# %%
import seaborn as sns

# %%
sns.relplot(data=p, x = 'Q1', y = 'Total')

# %%
sns.relplot(data=p, x = 'Q2', y = 'Total')

# %%
sns.relplot(data=p, x = 'Q3', y = 'Total')

# %%
sns.relplot(data=p, x = 'Q4', y = 'Total')

# %%
sns.relplot(data=p, x = 'Q5', y = 'Total')

# %%
sns.relplot(data=p, x = 'Q6', y = 'Total')

# %%
sns.lineplot(x="Q1", y="Total", data=p)
# Out:
# <Axes: xlabel='Q1', ylabel='Total'>

# %%
sns.lineplot(x="Q2", y="Total", data=p)
# Out:
# <Axes: xlabel='Q2', ylabel='Total'>

# %%
sns.lineplot(x="Q3", y="Total", data=p)
# Out:
# <Axes: xlabel='Q3', ylabel='Total'>

# %%
sns.lineplot(x="Q4", y="Total", data=p)
# Out:
# <Axes: xlabel='Q4', ylabel='Total'>

# %%
sns.lineplot(x="Q5", y="Total", data=p)
# Out:
# <Axes: xlabel='Q5', ylabel='Total'>

# %%
sns.lineplot(x="Q6", y="Total", data=p)
# Out:
# <Axes: xlabel='Q6', ylabel='Total'>
